# %%
#punto 1a)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def fun(x):
    y = e**-x*(x**3-5)
    return y

# %%
x = linspace(0,7,201)

# %%
y = fun(x)

# %%
plt.plot(x,y)

# %%
#punto 2

# %%
r1 = np.array([1,2,1])
r2 = np.array([3,4,5])

# %%
p1 = np.array(r1[0]/((r1[0])**2+(r1[1])**2+(r1[2])**2)**1/2)
p2 = np.array(r1[1]/((r1[0])**2+(r1[1])**2+(r1[2])**2)**1/2)
p3 = np.array(r1[2]/((r1[0])**2+(r1[1])**2+(r1[2])**2)**1/2)

# %%
n1 = np.array([p1,p2,p3])

# %%
producto_p = np.array((r1[0])*(r2[0])+(r1[1])*(r2[1])+(r1[2])*(r2[2]))

# %%
l1 = np.array(producto_p*n1[0])
l2 = np.array(producto_p*n1[0])
l3 = np.array(producto_p*n1[0])
lt = np.array([l1,l2,l3])

# %%
n2 = np.array([(r2[0]-lt[0]),(r2[1]-lt[1]),(r2[2]-lt[2])])

# %%
i = np.array(n1[1]*n2[2]-n1[2]*n2[1])

# %%
j = np.array(-(n1[0]*n2[2]-n1[2]*n2[0]))

# %%
k = np.array(n1[0]*n2[1]-n1[1]*n2[0])

# %%
n3 = np.array([i,j,k])

# %%
base_ort = np.array([n1,n2,n3])

# %%
def f(x,y):
    h = (x-3)**2+(y-3)**2-x*y
    return h

# %%
def g(x,y):
    h = y-(x-1)**2
    return h

# %%
def h(x,y):
    k = f(x,y)**2+g(x,y)**2
    return k

# %%
#punto 3a

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
s = np.linspace(0, 3, 200)
x,y = np.meshgrid(s,s)

# %%
k0 = f(x,y)
k1 = g(x,y)
k2 = h(x,y)
k3 = (h(x,y))**1/2

# %%
fig = plt.figure(figsize=(30,20))
ax1 = fig.add_subplot(221, projection="3d",fc=(0,0,0,0))
ax2 = fig.add_subplot(222, projection="3d",fc=(0,0,0,0))
ax3 = fig.add_subplot(223, fc=(0,0,0,0),aspect='equal')
ax4 = fig.add_subplot(224, fc=(0,0,0,0),aspect='equal')
ax1.scatter(x, y, k1,c=k1.flatten(),cmap="viridis",alpha=0.7)
ax2.plot_surface(x, y, k0,cmap="inferno",alpha=0.9,edgecolor="none")
im3=ax3.contourf(x,y,k3,levels=45,cmap="rainbow")
im4=ax4.pcolormesh(x,y,k2,cmap="jet")
plt.colorbar(im3,ax=ax3)
plt.colorbar(im4,ax=ax4)

# %%
#punto 3b

# %%
k0
# Out:
# array([[-1.        , -0.97007651, -0.94060756, ..., -3.88030605,
#         -3.93992576, -4.        ],
#        [-0.98492462, -0.95500114, -0.92553218, ..., -3.86523068,
#         -3.92485038, -3.98492462],
#        [-0.96984925, -0.93992576, -0.91045681, ..., -3.8501553 ,
#         -3.90977501, -3.96984925],
#        ...,
#        [ 1.96984925,  1.99977273,  2.02924169, ..., -0.91045681,
#         -0.97007651, -1.03015075],
#        [ 1.98492462,  2.01484811,  2.04431706, ..., -0.89538143,
#         -0.95500114, -1.01507538],
#        [ 2.        ,  2.02992349,  2.05939244, ..., -0.88030605,
#         -0.93992576, -1.        ]])

# %%
k1
# Out:
# array([[325.        , 321.7010892 , 318.43730458, ...,  96.07313911,
#          96.52710585,  97.        ],
#        [321.73011727, 318.44029024, 315.18557538, ...,  93.54441223,
#          93.99273597,  94.45985101],
#        [318.49316956, 315.21242599, 311.96678121, ...,  91.06052524,
#          91.50332777,  91.96478612],
#        ...,
#        [ 84.8966701 ,  82.60349503,  80.35465123, ...,  78.58934315,
#          79.50515907,  80.42505354],
#        [ 84.94401662,  82.64789835,  80.39621943, ...,  79.36581853,
#          80.28801844,  81.21428287],
#        [ 85.        ,  82.70081612,  80.4461803 , ...,  80.13878171,
#          81.06736529,  82.        ]])

# %%
k2
# Out:
# array([[325.        , 321.7010892 , 318.43730458, ...,  96.07313911,
#          96.52710585,  97.        ],
#        [321.73011727, 318.44029024, 315.18557538, ...,  93.54441223,
#          93.99273597,  94.45985101],
#        [318.49316956, 315.21242599, 311.96678121, ...,  91.06052524,
#          91.50332777,  91.96478612],
#        ...,
#        [ 84.8966701 ,  82.60349503,  80.35465123, ...,  78.58934315,
#          79.50515907,  80.42505354],
#        [ 84.94401662,  82.64789835,  80.39621943, ...,  79.36581853,
#          80.28801844,  81.21428287],
#        [ 85.        ,  82.70081612,  80.4461803 , ...,  80.13878171,
#          81.06736529,  82.        ]])

# %%
k3
# Out:
# array([[162.5       , 160.8505446 , 159.21865229, ...,  48.03656956,
#          48.26355292,  48.5       ],
#        [160.86505863, 159.22014512, 157.59278769, ...,  46.77220611,
#          46.99636798,  47.2299255 ],
#        [159.24658478, 157.606213  , 155.9833906 , ...,  45.53026262,
#          45.75166389,  45.98239306],
#        ...,
#        [ 42.44833505,  41.30174752,  40.17732561, ...,  39.29467157,
#          39.75257954,  40.21252677],
#        [ 42.47200831,  41.32394917,  40.19810972, ...,  39.68290927,
#          40.14400922,  40.60714144],
#        [ 42.5       ,  41.35040806,  40.22309015, ...,  40.06939086,
#          40.53368264,  41.        ]])
